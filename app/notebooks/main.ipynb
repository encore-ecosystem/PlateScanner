# %%
import mlflow

# %%
mlflow.set_tracking_uri(uri="http://localhost:5000")

# %%
mlflow.set_experiment("MLflow Quickstart")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 502 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 944 (2 times)]
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\urllib3\connectionpool.py:934, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     933 try:
# --> 934     retries = retries.increment(method, url, response=response, _pool=self)
#     935 except MaxRetryError:
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=12334): Max retries exceeded with url: http://localhost:5000/api/2.0/mlflow/experiments/get-by-name?experiment_name=MLflow+Quickstart (Caused by ResponseError('too many 502 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\utils\rest_utils.py:189, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     188 try:
# --> 189     return _get_http_response_with_retries(
#     190         method,
#     191         url,
#     192         max_retries,
#     193         backoff_factor,
#     194         backoff_jitter,
#     195         retry_codes,
#     196         raise_on_status,
#     197         headers=headers,
#     198         verify=host_creds.verify,
#     199         timeout=timeout,
#     200         respect_retry_after_header=respect_retry_after_header,
#     201         **kwargs,
#     202     )
#     203 except requests.exceptions.Timeout as to:
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\utils\request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\requests\adapters.py:691, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     690 if isinstance(e.reason, ResponseError):
# --> 691     raise RetryError(e, request=request)
#     693 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPConnectionPool(host='127.0.0.1', port=12334): Max retries exceeded with url: http://localhost:5000/api/2.0/mlflow/experiments/get-by-name?experiment_name=MLflow+Quickstart (Caused by ResponseError('too many 502 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mlflow.set_experiment("MLflow Quickstart")
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\tracking\fluent.py:145, in set_experiment(experiment_name, experiment_id)
#     143 client = MlflowClient()
#     144 if experiment_id is None:
# --> 145     experiment = client.get_experiment_by_name(experiment_name)
#     146     if not experiment:
#     147         _logger.info(
#     148             "Experiment with name '%s' does not exist. Creating a new experiment.",
#     149             experiment_name,
#     150         )
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\tracking\client.py:1249, in MlflowClient.get_experiment_by_name(self, name)
#    1217 def get_experiment_by_name(self, name: str) -> Optional[Experiment]:
#    1218     """Retrieve an experiment by experiment name from the backend store
#    1219
#    1220     Args:
#    (...)
#    1247         Lifecycle_stage: active
#    1248     """
# -> 1249     return self._tracking_client.get_experiment_by_name(name)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:484, in TrackingServiceClient.get_experiment_by_name(self, name)
#     476 def get_experiment_by_name(self, name):
#     477     """
#     478     Args:
#     479         name: The experiment name.
#    (...)
#     482         :py:class:`mlflow.entities.Experiment`
#     483     """
# --> 484     return self.store.get_experiment_by_name(name)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\store\tracking\rest_store.py:519, in RestStore.get_experiment_by_name(self, experiment_name)
#     517 try:
#     518     req_body = message_to_json(GetExperimentByName(experiment_name=experiment_name))
# --> 519     response_proto = self._call_endpoint(GetExperimentByName, req_body)
#     520     return Experiment.from_proto(response_proto.experiment)
#     521 except MlflowException as e:
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\store\tracking\rest_store.py:82, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      80     endpoint, method = _METHOD_TO_INFO[api]
#      81 response_proto = api.Response()
# ---> 82 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\utils\rest_utils.py:365, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     363 if method == "GET":
#     364     call_kwargs["params"] = json_body
# --> 365     response = http_request(**call_kwargs)
#     366 else:
#     367     call_kwargs["json"] = json_body
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\utils\rest_utils.py:212, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     210     raise InvalidUrlException(f"Invalid url: {url}") from iu
#     211 except Exception as e:
# --> 212     raise MlflowException(f"API request to {url} failed with exception {e}")
#
# MlflowException: API request to http://localhost:5000/api/2.0/mlflow/experiments/get-by-name failed with exception HTTPConnectionPool(host='127.0.0.1', port=12334): Max retries exceeded with url: http://localhost:5000/api/2.0/mlflow/experiments/get-by-name?experiment_name=MLflow+Quickstart (Caused by ResponseError('too many 502 error responses'))

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

# %%
# set the experiment id
mlflow.set_experiment(experiment_id="0")

mlflow.autolog()
db = load_diabetes()

X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# Create and train models.
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
rf.fit(X_train, y_train)

# Use the model to make predictions on the test dataset.
predictions = rf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 502 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 944 (2 times)]
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\urllib3\connectionpool.py:934, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     933 try:
# --> 934     retries = retries.increment(method, url, response=response, _pool=self)
#     935 except MaxRetryError:
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=12334): Max retries exceeded with url: http://localhost:5000/api/2.0/mlflow/experiments/get?experiment_id=0 (Caused by ResponseError('too many 502 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\utils\rest_utils.py:189, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     188 try:
# --> 189     return _get_http_response_with_retries(
#     190         method,
#     191         url,
#     192         max_retries,
#     193         backoff_factor,
#     194         backoff_jitter,
#     195         retry_codes,
#     196         raise_on_status,
#     197         headers=headers,
#     198         verify=host_creds.verify,
#     199         timeout=timeout,
#     200         respect_retry_after_header=respect_retry_after_header,
#     201         **kwargs,
#     202     )
#     203 except requests.exceptions.Timeout as to:
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\utils\request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\requests\adapters.py:691, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     690 if isinstance(e.reason, ResponseError):
# --> 691     raise RetryError(e, request=request)
#     693 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPConnectionPool(host='127.0.0.1', port=12334): Max retries exceeded with url: http://localhost:5000/api/2.0/mlflow/experiments/get?experiment_id=0 (Caused by ResponseError('too many 502 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[5], line 2
#       1 # set the experiment id
# ----> 2 mlflow.set_experiment(experiment_id="0")
#       4 mlflow.autolog()
#       5 db = load_diabetes()
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\tracking\fluent.py:157, in set_experiment(experiment_name, experiment_id)
#     155         experiment = client.get_experiment(experiment_id)
#     156 else:
# --> 157     experiment = client.get_experiment(experiment_id)
#     158     if experiment is None:
#     159         raise MlflowException(
#     160             message=f"Experiment with ID '{experiment_id}' does not exist.",
#     161             error_code=RESOURCE_DOES_NOT_EXIST,
#     162         )
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\tracking\client.py:1215, in MlflowClient.get_experiment(self, experiment_id)
#    1183 def get_experiment(self, experiment_id: str) -> Experiment:
#    1184     """Retrieve an experiment by experiment_id from the backend store
#    1185
#    1186     Args:
#    (...)
#    1213       Lifecycle_stage: active
#    1214     """
# -> 1215     return self._tracking_client.get_experiment(experiment_id)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:474, in TrackingServiceClient.get_experiment(self, experiment_id)
#     466 def get_experiment(self, experiment_id):
#     467     """
#     468     Args:
#     469         experiment_id: The experiment ID returned from ``create_experiment``.
#    (...)
#     472         :py:class:`mlflow.entities.Experiment`
#     473     """
# --> 474     return self.store.get_experiment(experiment_id)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\store\tracking\rest_store.py:138, in RestStore.get_experiment(self, experiment_id)
#     127 """
#     128 Fetch the experiment from the backend store.
#     129
#    (...)
#     135     otherwise raises an Exception.
#     136 """
#     137 req_body = message_to_json(GetExperiment(experiment_id=str(experiment_id)))
# --> 138 response_proto = self._call_endpoint(GetExperiment, req_body)
#     139 return Experiment.from_proto(response_proto.experiment)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\store\tracking\rest_store.py:82, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      80     endpoint, method = _METHOD_TO_INFO[api]
#      81 response_proto = api.Response()
# ---> 82 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\utils\rest_utils.py:365, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     363 if method == "GET":
#     364     call_kwargs["params"] = json_body
# --> 365     response = http_request(**call_kwargs)
#     366 else:
#     367     call_kwargs["json"] = json_body
#
# File ~\Documents\Programming\PlateScanner\.venv\Lib\site-packages\mlflow\utils\rest_utils.py:212, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     210     raise InvalidUrlException(f"Invalid url: {url}") from iu
#     211 except Exception as e:
# --> 212     raise MlflowException(f"API request to {url} failed with exception {e}")
#
# MlflowException: API request to http://localhost:5000/api/2.0/mlflow/experiments/get failed with exception HTTPConnectionPool(host='127.0.0.1', port=12334): Max retries exceeded with url: http://localhost:5000/api/2.0/mlflow/experiments/get?experiment_id=0 (Caused by ResponseError('too many 502 error responses'))
